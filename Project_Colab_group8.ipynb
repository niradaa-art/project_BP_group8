# %% [markdown]
# <a href="https://colab.research.google.com/github/niradaa-art/project_BP_group8/blob/main/Project_Colab_group8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Group 8 MONEY_knock_everyting
# นางสาวณิรดา อนุนิวัฒน์ 673020252-4
#
# นายธนพล ท้าวนอ 673020253-2
#
# นางสาวสุพิชชา คำสิงห์ 673020265-5
#
# นางสาวอาทิติญา ชาชัย 673020270-2
#
# ---

# %% [markdown]
# #Data
# https://drive.google.com/drive/folders/1m6hp8l6iMB1u-a1yNK4laewgrUTy_Bnl?usp=drive_link

# %% [markdown]
# #Connect Google Drive

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
base_path = '/content/drive/MyDrive/datasets_budget'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # ชุดข้อมูลที่ 1 รายการจัดสรรงบประมาณระดับจังหวัด ปีงบประมาณ พ.ศ.2566

# %%
import pandas as pd

budget = pd.read_csv(f"{base_path}/provincial_budget.csv", sep="|")
budget
# Out:
#        fy changwad_area_name                  min_name  \
# 0      66           ส่วนกลาง                    งบกลาง
# 1      66           ส่วนกลาง                    งบกลาง
# 2      66           ส่วนกลาง                    งบกลาง
# 3      66           ส่วนกลาง                    งบกลาง
# 4      66           ส่วนกลาง                    งบกลาง
# ...    ..                ...                       ...
# 17403  66    จังหวัดนราธิวาส    จังหวัดและกลุ่มจังหวัด
# 17404  66    จังหวัดนราธิวาส  องค์กรปกครองส่วนท้องถิ่น
# 17405  66    จังหวัดนราธิวาส  องค์กรปกครองส่วนท้องถิ่น
# 17406  66    จังหวัดนราธิวาส  องค์กรปกครองส่วนท้องถิ่น
# 17407  66    จังหวัดนราธิวาส  องค์กรปกครองส่วนท้องถิ่น
#
#                                agc_name  \
# 0                                งบกลาง
# 1                                งบกลาง
# 2                                งบกลาง
# 3                                งบกลาง
# 4                                งบกลาง
# ...                                 ...
# ...

# %%
budget.shape
# Out:
# (17408, 8)

# %%
budget.columns
# Out:
# Index(['fy', 'changwad_area_name', 'min_name', 'agc_name', 'plan_name',
#        'output_name', 'objc', 'budget'],
#       dtype='object')

# %%
budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17408 entries, 0 to 17407
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   fy                  17408 non-null  int64
#  1   changwad_area_name  17408 non-null  object
#  2   min_name            17408 non-null  object
#  3   agc_name            17408 non-null  object
#  4   plan_name           17408 non-null  object
#  5   output_name         17408 non-null  object
#  6   objc                17408 non-null  object
#  7   budget              17408 non-null  int64
# dtypes: int64(2), object(6)
# memory usage: 1.1+ MB

# %% [markdown]
# # ชุดข้อมูลที่ 2 ผลิตภัณฑ์มวลรวมของประเทศ

# %%
import pandas as pd

gpp = pd.read_csv(f"{base_path}/gdp.csv")
gpp
# Out:
#       TIME_PERIOD                                NA_STAT  \
# 0            2538  ผลิตภัณฑ์มวลรวมในประเทศ ณ ราคาประจำปี
# 1            2539  ผลิตภัณฑ์มวลรวมในประเทศ ณ ราคาประจำปี
# 2            2540  ผลิตภัณฑ์มวลรวมในประเทศ ณ ราคาประจำปี
# 3            2541  ผลิตภัณฑ์มวลรวมในประเทศ ณ ราคาประจำปี
# 4            2542  ผลิตภัณฑ์มวลรวมในประเทศ ณ ราคาประจำปี
# ...           ...                                    ...
# 7390         2562  ผลิตภัณฑ์มวลรวมในประเทศ ณ ราคาประจำปี
# 7391         2563  ผลิตภัณฑ์มวลรวมในประเทศ ณ ราคาประจำปี
# 7392         2564  ผลิตภัณฑ์มวลรวมในประเทศ ณ ราคาประจำปี
# 7393         2565  ผลิตภัณฑ์มวลรวมในประเทศ ณ ราคาประจำปี
# 7394         2566  ผลิตภัณฑ์มวลรวมในประเทศ ณ ราคาประจำปี
#
#                                  NI     AREA     CWT UNIT_MUL UNIT   FREQ  \
# 0      ผลิตภัณฑ์มวลรวมจังหวัด (GPP)  ภาคกลาง  ลพบุรี     ล้าน  บาท  รายปี
# 1      ผลิตภัณฑ์มวลรวมจังหวัด (GPP)  ภาคกลาง  ลพบุรี     ล้าน  บาท  รายปี
# ...

# %%
gpp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7395 entries, 0 to 7394
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TIME_PERIOD  7395 non-null   int64
#  1   NA_STAT      7395 non-null   object
#  2   NI           7395 non-null   object
#  3   AREA         7395 non-null   object
#  4   CWT          7395 non-null   object
#  5   UNIT_MUL     7395 non-null   object
#  6   UNIT         7395 non-null   object
#  7   FREQ         7395 non-null   object
#  8   Value        7395 non-null   float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 520.1+ KB

# %% [markdown]
# # ชุดข้อมูลชุดที่ 3 รายชื่อพรรคการเมืองระดับจังหวัด

# %%
import pandas as pd

party = pd.read_csv(f"{base_path}/partylist.csv")
party
# Out:
#         changwad_area_name    party_name
# 0            จังหวัดกระบี่     ภูมิใจไทย
# 1            กรุงเทพมหานคร       ก้าวไกล
# 2         จังหวัดกาญจนบุรี      เพื่อไทย
# 3         จังหวัดกาฬสินธุ์      เพื่อไทย
# 4         จังหวัดกำแพงเพชร  พลังประชารัฐ
# ..                     ...           ...
# 72        จังหวัดเพชรบูรณ์  พลังประชารัฐ
# 73              จังหวัดเลย      เพื่อไทย
# 74             จังหวัดแพร่      เพื่อไทย
# 75       จังหวัดแม่ฮ่องสอน  ประชาธิปัตย์
# 76  จังหวัดพระนครศรีอยุธยา     ภูมิใจไทย
#
# [77 rows x 2 columns]

# %%
party.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   changwad_area_name  77 non-null     object
#  1   party_name          77 non-null     object
# dtypes: object(2)
# memory usage: 1.3+ KB

# %% [markdown]
# # Clean Data

# %% [markdown]
# ##ตรวจสอบ Missing Values

# %%
budget.isnull().sum()
# Out:
# fy                    0
# changwad_area_name    0
# min_name              0
# agc_name              0
# plan_name             0
# output_name           0
# objc                  0
# budget                0
# dtype: int64

# %% [markdown]
# ##ตรวจสอบ Duplicate

# %%
budget.duplicated().sum()
# Out:
# np.int64(1)

# %%
budget[budget.duplicated()]
#-----------------------------------------------
#รายการงบประมาณที่มีข้อมูลเหมือนกันอาจเป็นรายการงบประมาณคนละรายการจริง ๆ
#-----------------------------------------------
# Out:
#     fy changwad_area_name min_name agc_name  \
# 13  66           ส่วนกลาง   งบกลาง   งบกลาง
#
#                                        plan_name  \
# 13  แผนงานบริหารเพื่อรองรับกรณีฉุกเฉินหรือจำเป็น
#
#                                           output_name     objc       budget
# 13  รายจ่ายงบกลาง : เงินสำรองจ่ายเพื่อกรณีฉุกเฉินห...  งบลงทุน  27720000000

# %% [markdown]
# ##ตรวจสอบข้อมูลผิดปกติ

# %%
#ตรวจสอบ columm budget
df["budget"].describe()
# Out:
# count    1.740800e+04
# mean     1.828848e+08
# std      4.147141e+09
# min      1.100000e+03
# 25%      1.020000e+06
# 50%      5.856850e+06
# 75%      3.384408e+07
# max      3.227900e+11
# Name: budget, dtype: float64

# %%
#งบประมาณมีการกระจายค่อนข้างกว้าง
#ตรวจสอบค่า Budget ที่สูงมากก่อนทำ Visualization
df.sort_values("budget", ascending=False).head(10)
# Out:
#        fy changwad_area_name  \
# 5      66           ส่วนกลาง
# 6916   66      กรุงเทพมหานคร
# 8602   66      กรุงเทพมหานคร
# 9153   66      กรุงเทพมหานคร
# 9324   66      กรุงเทพมหานคร
# 10666  66     จังหวัดนนทบุรี
# 9996   66      กรุงเทพมหานคร
# 4      66           ส่วนกลาง
# 8      66           ส่วนกลาง
# 6730   66      กรุงเทพมหานคร
#
#                                                 min_name  \
# 5                                                 งบกลาง
# 6916                                      กระทรวงการคลัง
# 8602                                      กระทรวงมหาดไทย
# 9153                                   กระทรวงศึกษาธิการ
# 9324                                    กระทรวงสาธารณสุข
# 10666                                   กระทรวงสาธารณสุข
# 9996   ส่วนราชการไม่สังกัดสำนักนายกรัฐมนตรี กระทรวง ห...
# 4                                                 งบกลาง
# 8                                                 งบกลาง
# 6730                                       กระทรวงกลาโหม
#
# ...

# %% [markdown]
# ##ตรวจสอบค่าของตัวแปร Categorical

# %%
#จำนวนจังหวัด
df["changwad_area_name"].nunique()
# Out:
# 78

# %%
#ดูจำนวนรายการแต่ละจังหวัด
df["changwad_area_name"].value_counts()
# Out:
# changwad_area_name
# กรุงเทพมหานคร         3907
# จังหวัดนนทบุรี         665
# จังหวัดเชียงใหม่       349
# จังหวัดสงขลา           306
# จังหวัดชลบุรี          279
#                       ...
# จังหวัดสิงห์บุรี       105
# จังหวัดสมุทรสาคร       101
# จังหวัดอ่างทอง          95
# จังหวัดสมุทรสงคราม      88
# ส่วนกลาง                16
# Name: count, Length: 78, dtype: int64

# %%
#จำนวนกระทรวง
df["min_name"].value_counts()
# Out:
# min_name
# กระทรวงเกษตรและสหกรณ์                                                                                  2460
# กระทรวงศึกษาธิการ                                                                                      2093
# กระทรวงการอุดมศึกษา วิทยาศาสตร์ วิจัยและนวัตกรรม                                                       1665
# กระทรวงคมนาคม                                                                                          1484
# กระทรวงทรัพยากรธรรมชาติและสิ่งแวดล้อม                                                                  1375
# จังหวัดและกลุ่มจังหวัด                                                                                 1205
# กระทรวงมหาดไทย                                                                                         1099
# กระทรวงสาธารณสุข                                                                                       1018
# ...

# %%
#ประเภทแผนงาน
df["plan_name"].value_counts()
# Out:
# plan_name
# แผนงานพื้นฐานด้านการพัฒนาและเสริมสร้างศักยภาพทรัพยากรมนุษย์                                     2307
# แผนงานพื้นฐานด้านการสร้างความสามารถในการแข่งขัน                                                 2181
# แผนงานบุคลากรภาครัฐ                                                                             1288
# แผนงานยุทธศาสตร์ส่งเสริมการพัฒนาจังหวัดและกลุ่มจังหวัดแบบบูรณาการ                               1205
# แผนงานยุทธศาสตร์การเกษตรสร้างมูลค่า                                                              821
#                                                                                                 ...
# แผนงานยุทธศาสตร์พัฒนาและเสริมสร้างการเมืองในระบอบประชาธิปไตยอันมีพระมหากษัตริย์ทรงเป็นประมุข       6
# แผนงานยุทธศาสตร์การวิจัยและพัฒนานวัตกรรม                                                           5
# แผนงานยุทธศาสตร์พัฒนาศักยภาพด้านวิทยาศาสตร์ เทคโนโลยี และนวัตกรรม                                  4
# ...

# %%
#ประเภทค่าใช้จ่าย
df["objc"].value_counts()
# Out:
# objc
# งบลงทุน          10013
# งบดำเนินงาน       2942
# งบอุดหนุน         2759
# งบรายจ่ายอื่น      984
# งบบุคลากร          710
# Name: count, dtype: int64

# %% [markdown]
# # เตรียมข้อมูล

# %% [markdown]
# ## ตาราง GPP เฉพาะปี พ.ศ.2566

# %%
# เลือกเฉพาะปี 2566
gpp_2566 = gpp[gpp["TIME_PERIOD"] == 2566]
gpp_2566
# Out:
#       TIME_PERIOD                                NA_STAT  \
# 28           2566  ผลิตภัณฑ์มวลรวมในประเทศ ณ ราคาประจำปี
# 57           2566  ผลิตภัณฑ์มวลรวมในประเทศ ณ ราคาประจำปี
# 86           2566  ผลิตภัณฑ์มวลรวมในประเทศ ณ ราคาประจำปี
# 115          2566  ผลิตภัณฑ์มวลรวมในประเทศ ณ ราคาประจำปี
# 144          2566  ผลิตภัณฑ์มวลรวมในประเทศ ณ ราคาประจำปี
# ...           ...                                    ...
# 7278         2566  ผลิตภัณฑ์มวลรวมในประเทศ ณ ราคาประจำปี
# 7307         2566  ผลิตภัณฑ์มวลรวมในประเทศ ณ ราคาประจำปี
# 7336         2566  ผลิตภัณฑ์มวลรวมในประเทศ ณ ราคาประจำปี
# 7365         2566  ผลิตภัณฑ์มวลรวมในประเทศ ณ ราคาประจำปี
# 7394         2566  ผลิตภัณฑ์มวลรวมในประเทศ ณ ราคาประจำปี
#
#                                  NI  \
# 28     ผลิตภัณฑ์มวลรวมจังหวัด (GPP)
# 57     ผลิตภัณฑ์มวลรวมจังหวัด (GPP)
# 86     ผลิตภัณฑ์มวลรวมจังหวัด (GPP)
# 115    ผลิตภัณฑ์มวลรวมจังหวัด (GPP)
# 144              ผลิตภัณฑ์ภาค (GRP)
# ...                             ...
# ...

# %% [markdown]
# ## ตาราง งบประมาณ แสดงเฉพาะจังหวัด แผนงาน ประเภทงบประมาณ และ Budget(หน่วย : ล้านบาท)

# %%
# เลือกเฉพาะคอลัมน์ที่ต้องการ
budget_df = budget[["changwad_area_name","plan_name",
         "objc","budget"]]

# แปลง Budget เป็นตัวเลข และเปลี่ยนหน่วยเป็นล้านบาท
budget_df["budget"] = pd.to_numeric(budget["budget"], errors="coerce") /1_000_000
budget_df
# Out:
# /tmp/ipykernel_2065/2042864936.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   budget_df["budget"] = pd.to_numeric(budget["budget"], errors="coerce") /1_000_000
#       changwad_area_name                                          plan_name  \
# 0               ส่วนกลาง  แผนงานยุทธศาสตร์พัฒนาระบบการเตรียมพร้อมแห่งชาต...
# 1               ส่วนกลาง                        แผนงานพื้นฐานด้านความมั่นคง
# 2               ส่วนกลาง             แผนงานยุทธศาสตร์เสริมสร้างพลังทางสังคม
# 3               ส่วนกลาง             แผนงานยุทธศาสตร์เสริมสร้างพลังทางสังคม
# 4               ส่วนกลาง            แผนงานยุทธศาสตร์สร้างหลักประกันทางสังคม
# ...                  ...                                                ...
# ...

# %% [markdown]
# ## ตาราง งบประมาณรวมแต่ละจังหวัด

# %%
# เลือกเฉพาะคอลัมน์ที่ต้องการ
df = df[["changwad_area_name", "budget"]]

# แปลง Budget เป็นตัวเลข
df["budget"] = pd.to_numeric(df["budget"], errors="coerce")

# รวมงบประมาณของแต่ละจังหวัด
budget_province = df.groupby("changwad_area_name", as_index=False)["budget"].sum()
budget_province
# Out:
#    changwad_area_name        budget
# 0       กรุงเทพมหานคร  5.247677e+06
# 1       จังหวัดกระบี่  5.320809e+03
# 2    จังหวัดกาญจนบุรี  7.662155e+03
# 3    จังหวัดกาฬสินธุ์  6.120248e+03
# 4    จังหวัดกำแพงเพชร  5.683986e+03
# ..                ...           ...
# 73   จังหวัดเพชรบูรณ์  6.759399e+03
# 74         จังหวัดเลย  6.499287e+03
# 75        จังหวัดแพร่  4.861729e+03
# 76  จังหวัดแม่ฮ่องสอน  2.754794e+03
# 77           ส่วนกลาง  5.904700e+05
#
# [78 rows x 2 columns]
